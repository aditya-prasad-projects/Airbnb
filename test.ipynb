# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import *
import pandas as pd
from pyspark.sql import functions as F
from pyspark.sql import types as T
from pyspark import SparkFiles

# %%
spark = SparkSession\
        .builder\
        .master("local")\
        .config("spark.files.overwrite", True)\
        .getOrCreate()

# %%
boston_reviews_df = spark.read.csv("data/Boston/2020/June/reviews.csv", header=True)
boston_reviews_df = boston_reviews_df.withColumnRenamed("id", "review_id")
boston_reviews_df.toPandas()
# Out:
#                                                listing_id  review_id  \
# 0                                                    3781   37776825
# 1                                                    3781   41842494
# 2                                                    3781   45282151
# 3                                                    3781   49022647
# 4                                                    3781   52503327
# ...                                                   ...        ...
# 179901                                           43442619  625246771
# 179902                                           43442619  626642174
# 179903  At my time of stay (05/20) fees were exorbitant."       None
# 179904                                           43489770  627807090
# 179905                                           43508236  626656633
#
#               date reviewer_id reviewer_name  \
# 0       2015-07-10    36059247          Greg
# 1       2015-08-09    10459388           Tai
# 2       2015-09-01    12264652        Damien
# 3       2015-09-30    41426327          Mike
# 4       2015-10-30    15151513          Ivan
# ...            ...         ...           ...
# 179901  2020-05-18    41655471        Adrian
# 179902  2020-05-29    72655982         Eliot
# 179903        None        None          None
# 179904  2020-06-05   347912013         Keiji
# 179905  2020-05-29   234834352        Dennis
#
#                                                  comments
# 0       The apartment was as advertised and Frank was ...
# 1       It was a pleasure to stay at Frank's place. Th...
# 2       The apartment description is entirely faithful...
# 3       Thoroughly enjoyed my time at Frank's home. Ha...
# 4       Great value for the money! This location has e...
# ...                                                   ...
# 179901  Highly recommend this place if you're visiting...
# 179902  View is great. A nice two bedroom. Park next d...
# 179903                                               None
# 179904                                       Perfect stay
# 179905                                  Always a pleasure
#
# [179906 rows x 6 columns]

# %%
boston_listings_df = spark.read.csv("data/Boston/2020/June/listings_original.csv", header=True)
boston_listings_df.count()
# Out:
# 3446

# %%
boston_listings_df.createOrReplaceTempView("boston_listings")

# %%
spark.sql("SELECT * FROM boston_listings WHERE id='3781'").toPandas()
# Out:
#      id                       name host_id host_name neighbourhood_group  \
# 0  3781  HARBORSIDE-Walk to subway    4804     Frank                None
#
#   neighbourhood  latitude  longitude        room_type price minimum_nights  \
# 0   East Boston  42.36413  -71.02991  Entire home/apt   125             28
#
#   number_of_reviews last_review reviews_per_month  \
# 0                16  2019-12-21              0.27
#
#   calculated_host_listings_count availability_365
# 0                              1               97

# %%
boston_reviews_df.createOrReplaceTempView("boston_reviews")

# %%
spark.sql("SELECT comments FROM boston_reviews WHERE listing_id='3781'").toPandas()
# Out:
#                                              comments
# 0   The apartment was as advertised and Frank was ...
# 1   It was a pleasure to stay at Frank's place. Th...
# 2   The apartment description is entirely faithful...
# 3   Thoroughly enjoyed my time at Frank's home. Ha...
# 4   Great value for the money! This location has e...
# 5   Frank was very accommodating throughout my sta...
# 6   Excellent! This was my second stay at the Jeff...
# 7   Frank was a wonderful and accommodating host. ...
# 8   Frank was great, the apartment has everything ...
# 9   Very nice. Comfortable apartment. Good locatio...
# 10  "Apartment was everything described. Very clea...
# 11  Frank's place is in a great part of East Bosto...
# 12  Franks' place is the ground floor unit in a 3 ...
# 13       Great place, amazing city, fantastic host!!!
# 14  My partner and I stayed at Frank's apartment f...
# 15  I liked very much this apartment rented by Fra...

# %%
boston_listings_df = spark.read.csv("data/Boston/2020/June/listings_original.csv", header=True)
boston_listings_df.toPandas()
# Out:
#             id                                               name    host_id  \
# 0         3781                          HARBORSIDE-Walk to subway       4804
# 1         5506     **$49 Special **   Private! Minutes to center!       8229
# 2         6695                     $99 Special!! Home Away! Condo       8229
# 3         8789                Curved Glass Studio/1bd facing Park      26988
# 4        10730                     Bright 1bed facing Golden Dome      26988
# ...        ...                                                ...        ...
# 3441  43690671            Beautiful 2 bedroom apartment/2nd floor  127718668
# 3442  43690782            Beautiful 2-bedroom apartment/3rd floor  127718668
# 3443  43715032                  2.bostonparkplaza · SUPERIOR ROOM  243931054
# 3444  43715125                                     Private Escape  349225095
# 3445  43729521  Evonify - MGH & Tufts - Luxury 2BR in Downtown PH  212359760
#
#               host_name neighbourhood_group neighbourhood           latitude  \
# 0                 Frank                None   East Boston           42.36413
# 1                 Terry                None       Roxbury           42.32981
# 2                 Terry                None       Roxbury           42.32994
# 3                  Anne                None      Downtown           42.35919
# 4                  Anne                None      Downtown            42.3584
# ...                 ...                 ...           ...                ...
# 3441               Muny                None    Dorchester           42.31281
# 3442               Muny                None    Dorchester           42.31235
# 3443  Boston Park Plaza                None      Downtown           42.35167
# 3444             Trevor                None    Dorchester           42.29637
# 3445            Evonify                None      Downtown  42.35106002536211
#
#               longitude        room_type price minimum_nights  \
# 0             -71.02991  Entire home/apt   125             28
# 1             -71.09559  Entire home/apt   145              3
# 2             -71.09351  Entire home/apt   169              3
# 3             -71.06265  Entire home/apt    99             91
# 4             -71.06185  Entire home/apt   150             91
# ...                 ...              ...   ...            ...
# 3441          -71.05591  Entire home/apt   170              1
# 3442           -71.0553  Entire home/apt   170              1
# 3443          -71.07058       Hotel room   100              1
# 3444          -71.07314     Private room    90              1
# 3445  -71.0650582770758  Entire home/apt   299              1
#
#      number_of_reviews last_review reviews_per_month  \
# 0                   16  2019-12-21              0.27
# 1                  107  2020-05-01              0.78
# 2                  115  2019-11-02              0.87
# 3                   25  2020-04-15              0.35
# 4                   32  2020-04-16              0.25
# ...                ...         ...               ...
# 3441                 0        None              None
# 3442                 0        None              None
# 3443                 0        None              None
# 3444                 0        None              None
# 3445                 0        None              None
#
#      calculated_host_listings_count availability_365
# 0                                 1               97
# 1                                 6              333
# 2                                 6              317
# 3                                 8              365
# 4                                 8              282
# ...                             ...              ...
# 3441                             13              363
# 3442                             13              361
# 3443                             13              348
# 3444                              1               84
# 3445                             46              365
#
# [3446 rows x 16 columns]

# %%
boston_neighbourhoods_df = spark.read.csv("data/Boston/2020/June/neighbourhoods.csv", header=True)
boston_neighbourhoods_df.toPandas()
# Out:
#    neighbourhood_group            neighbourhood
# 0                 None                  Allston
# 1                 None                 Back Bay
# 2                 None              Bay Village
# 3                 None              Beacon Hill
# 4                 None                 Brighton
# 5                 None              Charlestown
# 6                 None                Chinatown
# 7                 None               Dorchester
# 8                 None                 Downtown
# 9                 None              East Boston
# 10                None                   Fenway
# 11                None           Harbor Islands
# 12                None                Hyde Park
# 13                None            Jamaica Plain
# 14                None         Leather District
# 15                None    Longwood Medical Area
# 16                None                 Mattapan
# 17                None             Mission Hill
# 18                None                North End
# 19                None               Roslindale
# 20                None                  Roxbury
# 21                None             South Boston
# 22                None  South Boston Waterfront
# 23                None                South End
# 24                None                 West End
# 25                None             West Roxbury

# %%
neighbourhoods_list = ["Back Bay", 'South Boston', 'South End', 'Fenway', 'Allston', 'Dorchester', 'Downtown']
boston_neighbourhoods_df = spark.createDataFrame(neighbourhoods_list, StringType())
boston_neighbourhoods_df = boston_neighbourhoods_df.selectExpr("value as neighbourhood")

# %%
boston_top_neighbourhood = boston_listings_df.join(boston_neighbourhoods_df, ["neighbourhood"] , "left_semi")
boston_top_neighbourhood.toPandas()
# Out:
#      neighbourhood        id  \
# 0        South End     22354
# 1        South End    225224
# 2        South End    322593
# 3        South End    526970
# 4        South End    798957
# ...            ...       ...
# 1662  South Boston  43102656
# 1663  South Boston  43137883
# 1664  South Boston  43638802
# 1665  South Boston  43639005
# 1666  South Boston  43675011
#
#                                                    name    host_id host_name  \
# 0                    COPLEY SQ...19TH C.TWNHSE SUNNY RM      85770    Robert
# 1                                 4th floor office room      85770    Robert
# 2        Near Hospitals, 28 Day Bking Only,OutdoorSpace    1651480    Edward
# 3                      BACK BAY/COPLEY FIRST FLOOR ROOM      85770    Robert
# 4     ★Discounted★ NearHospitals★2floors★ 2 Baths,2beds    1651480    Edward
# ...                                                 ...        ...       ...
# 1662   Large bedroom in shared apartment with two males   10778805      Paul
# 1663                Spacious Queen Room in South Boston  297860058      June
# 1664  WB Quarters™ by STRB|Hangout|Priv. Room|Shared BA     814298    Thatch
# 1665  WB Quarters™ by STRB|Hangout|Priv. Room|Shared BA     814298    Thatch
# 1666   Beautiful 2bdrm, Near Convention Ctr, Waterfront     970787      Poli
#
#      neighbourhood_group  latitude  longitude        room_type price  \
# 0                   None  42.34496  -71.07486     Private room   148
# 1                   None  42.34643  -71.07503     Private room   105
# 2                   None  42.34232  -71.07594  Entire home/apt   125
# 3                   None  42.34523  -71.07282     Private room   148
# 4                   None  42.34232  -71.07594  Entire home/apt   347
# ...                  ...       ...        ...              ...   ...
# 1662                None  42.32958  -71.05638     Private room    50
# 1663                None  42.33393  -71.02503     Private room    48
# 1664                None  42.34313  -71.05606     Private room    90
# 1665                None  42.34301   -71.0573     Private room    90
# 1666                None  42.33973  -71.05129  Entire home/apt   200
#
#      minimum_nights number_of_reviews last_review reviews_per_month  \
# 0                 2               316  2019-12-13              2.93
# 1                 2               318  2020-03-21              3.02
# 2                28               408  2020-03-31              4.65
# 3                 2               175  2019-10-31              1.80
# 4                28               417  2020-04-30              4.82
# ...             ...               ...         ...               ...
# 1662             90                 0        None              None
# 1663             30                 0        None              None
# 1664             28                 0        None              None
# 1665             28                 0        None              None
# 1666              2                 0        None              None
#
#      calculated_host_listings_count availability_365
# 0                                 5               90
# 1                                 5               90
# 2                                 4               91
# 3                                 5               90
# 4                                 4                0
# ...                             ...              ...
# 1662                              3              363
# 1663                             31              364
# 1664                             92              141
# 1665                             92              144
# 1666                              3               62
#
# [1667 rows x 16 columns]

# %%
boston_top_neighbourhood = boston_top_neighbourhood.join(boston_reviews_df, boston_top_neighbourhood["id"] == boston_reviews_df["listing_id"], "left")
boston_top_neighbourhood.toPandas()
# Out:
#       neighbourhood        id  \
# 0          Downtown  15127120
# 1          Downtown  15127120
# 2          Downtown  15127120
# 3          Downtown  15127120
# 4          Downtown  15127120
# ...             ...       ...
# 64851       Allston  38131632
# 64852       Allston  38131632
# 64853       Allston  38131632
# 64854       Allston  38131632
# 64855       Allston  38131632
#
#                                                     name   host_id host_name  \
# 0                Sonder | Winthrop Square | Sleek Studio  12243051    Sonder
# 1                Sonder | Winthrop Square | Sleek Studio  12243051    Sonder
# 2                Sonder | Winthrop Square | Sleek Studio  12243051    Sonder
# 3                Sonder | Winthrop Square | Sleek Studio  12243051    Sonder
# 4                Sonder | Winthrop Square | Sleek Studio  12243051    Sonder
# ...                                                  ...       ...       ...
# 64851  Gorgeous space in vibrant area, steps to the t614  18110188     Cindy
# 64852  Gorgeous space in vibrant area, steps to the t614  18110188     Cindy
# 64853  Gorgeous space in vibrant area, steps to the t614  18110188     Cindy
# 64854  Gorgeous space in vibrant area, steps to the t614  18110188     Cindy
# 64855  Gorgeous space in vibrant area, steps to the t614  18110188     Cindy
#
#       neighbourhood_group  latitude  longitude        room_type price  ...  \
# 0                    None  42.35461  -71.05935  Entire home/apt    93  ...
# 1                    None  42.35461  -71.05935  Entire home/apt    93  ...
# 2                    None  42.35461  -71.05935  Entire home/apt    93  ...
# 3                    None  42.35461  -71.05935  Entire home/apt    93  ...
# 4                    None  42.35461  -71.05935  Entire home/apt    93  ...
# ...                   ...       ...        ...              ...   ...  ...
# 64851                None  42.35192  -71.12404  Entire home/apt   133  ...
# 64852                None  42.35192  -71.12404  Entire home/apt   133  ...
# 64853                None  42.35192  -71.12404  Entire home/apt   133  ...
# 64854                None  42.35192  -71.12404  Entire home/apt   133  ...
# 64855                None  42.35192  -71.12404  Entire home/apt   133  ...
#
#       last_review reviews_per_month calculated_host_listings_count  \
# 0      2019-12-22              1.54                             61
# 1      2019-12-22              1.54                             61
# 2      2019-12-22              1.54                             61
# 3      2019-12-22              1.54                             61
# 4      2019-12-22              1.54                             61
# ...           ...               ...                            ...
# 64851  2020-04-23              3.71                             48
# 64852  2020-04-23              3.71                             48
# 64853  2020-04-23              3.71                             48
# 64854  2020-04-23              3.71                             48
# 64855  2020-04-23              3.71                             48
#
#       availability_365 listing_id  review_id        date reviewer_id  \
# 0                  278   15127120  106168374  2016-10-04    17779001
# 1                  278   15127120  109610832  2016-10-22    93668045
# 2                  278   15127120  156889599  2017-06-01    77837346
# 3                  278   15127120  174024490  2017-07-24    14811727
# 4                  278   15127120  175756708  2017-07-29   122100846
# ...                ...        ...        ...         ...         ...
# 64851               78   38131632  614850845  2020-03-06    65276350
# 64852               78   38131632  616753381  2020-03-10    45242217
# 64853               78   38131632  617688297  2020-03-13   153288282
# 64854               78   38131632  618083877  2020-03-14   313838678
# 64855               78   38131632  622959291  2020-04-23   344369351
#
#       reviewer_name                                           comments
# 0          JeanEric  Spotlessly clean apartment & was exactly as ad...
# 1             Björn  Einhver besta mögulega staðsetning í Boston. L...
# 2            Mogens  It is placed in heart of Boston, close to ever...
# 3          Courtney                          Nice location, easy stay.
# 4      Marie-Claude  Bien situé. Très près transport en commun et p...
# ...             ...                                                ...
# 64851         Patty                                  Es un apartamento
# 64852           A&J  Great space. Near many restaurants but also qu...
# 64853         Rowan  Lovely stay! Definitely a great place for food...
# 64854        Alisha                               Good place for value
# 64855       Adriana                                           Great!!!
#
# [64856 rows x 22 columns]

# %%
sentence = list(boston_reviews_df.select("comments").head(1)[0])
sentence
# Out:
# ['The apartment was as advertised and Frank was incredibly helpful through the entire process. I would definitely recommend this place.']

# %%
from textblob import TextBlob

# %%
TextBlob(sentence[0]).sentiment
# Out:
# Sentiment(polarity=0.3, subjectivity=0.6749999999999999)

# %%
sentence = list(boston_reviews_df.where("listing_id == 15127120").select("comments").head(2)[1])
TextBlob(sentence[0]).translate(to= 'en')
# Out:
# TextBlob("Some of the best possible location in Boston. Small apartment but there is everything you need. New and tidy.")

# %%
dorchester_neighbourhood_df = boston_top_neighbourhood.where("neighbourhood == 'Dorchester'")
dorchester_neighbourhood_df.toPandas()
# Out:
#       neighbourhood        id  \
# 0        Dorchester  22571244
# 1        Dorchester  22571244
# 2        Dorchester  22571244
# 3        Dorchester  22571244
# 4        Dorchester  22571244
# ...             ...       ...
# 19511    Dorchester  35238309
# 19512    Dorchester  35238309
# 19513    Dorchester  35238309
# 19514    Dorchester  35238309
# 19515    Dorchester  35238309
#
#                                                     name    host_id host_name  \
# 0      ✪2 Double beds 4mi to Downtown near subway fre...   25203946      Eder
# 1      ✪2 Double beds 4mi to Downtown near subway fre...   25203946      Eder
# 2      ✪2 Double beds 4mi to Downtown near subway fre...   25203946      Eder
# 3      ✪2 Double beds 4mi to Downtown near subway fre...   25203946      Eder
# 4      ✪2 Double beds 4mi to Downtown near subway fre...   25203946      Eder
# ...                                                  ...        ...       ...
# 19511  1 Private suite/bath-rm best location  locatio...  261646616    Joseph
# 19512  1 Private suite/bath-rm best location  locatio...  261646616    Joseph
# 19513  1 Private suite/bath-rm best location  locatio...  261646616    Joseph
# 19514  1 Private suite/bath-rm best location  locatio...  261646616    Joseph
# 19515  1 Private suite/bath-rm best location  locatio...  261646616    Joseph
#
#       neighbourhood_group  latitude  longitude        room_type price  ...  \
# 0                    None  42.30936  -71.06347     Private room    44  ...
# 1                    None  42.30936  -71.06347     Private room    44  ...
# 2                    None  42.30936  -71.06347     Private room    44  ...
# 3                    None  42.30936  -71.06347     Private room    44  ...
# 4                    None  42.30936  -71.06347     Private room    44  ...
# ...                   ...       ...        ...              ...   ...  ...
# 19511                None  42.31583  -71.05798  Entire home/apt   500  ...
# 19512                None  42.31583  -71.05798  Entire home/apt   500  ...
# 19513                None  42.31583  -71.05798  Entire home/apt   500  ...
# 19514                None  42.31583  -71.05798  Entire home/apt   500  ...
# 19515                None  42.31583  -71.05798  Entire home/apt   500  ...
#
#       last_review reviews_per_month calculated_host_listings_count  \
# 0      2019-06-13              0.34                             17
# 1      2019-06-13              0.34                             17
# 2      2019-06-13              0.34                             17
# 3      2019-06-13              0.34                             17
# 4      2019-06-13              0.34                             17
# ...           ...               ...                            ...
# 19511  2020-03-08              1.98                              4
# 19512  2020-03-08              1.98                              4
# 19513  2020-03-08              1.98                              4
# 19514  2020-03-08              1.98                              4
# 19515  2020-03-08              1.98                              4
#
#       availability_365 listing_id  review_id        date reviewer_id  \
# 0                  160   22571244  228392128  2018-01-19   162953953
# 1                  160   22571244  232850966  2018-02-06   108441156
# 2                  160   22571244  249045170  2018-04-01    50884175
# 3                  160   22571244  276689352  2018-06-14   126237644
# 4                  160   22571244  279053437  2018-06-19   140123458
# ...                ...        ...        ...         ...         ...
# 19511               95   35238309  571718747  2019-12-01   195425991
# 19512               95   35238309  601081009  2020-02-02    88231857
# 19513               95   35238309  607736226  2020-02-18    14250998
# 19514               95   35238309  613056113  2020-03-01   326248264
# 19515               95   35238309  615773999  2020-03-08   126410292
#
#       reviewer_name                                           comments
# 0            Samuel  Really a nice stay. Warm accommodations. A lot...
# 1      Loise Coleen  This place is a wonderful value in a very nice...
# 2           Marcelo  Eder, is the best host I had so far! He’s amaz...
# 3            Gloria  La casa è  molto confortevole e il marito di E...
# 4                 F  Located close to Boston, this place is a home ...
# ...             ...                                                ...
# 19511         Janet  This is a beautiful old house. But maybe some ...
# 19512         Deniz  We stayed at Joe’s place during our Boston tri...
# 19513        Raquel  It's a beautiful space, roomy, clean, and comf...
# 19514          Liam  Very nice place to stay if you’re looking to s...
# 19515       Douglas                   Great spot to stay while in town
#
# [19516 rows x 22 columns]

# %%
dorchester_neighbourhood_df.createOrReplaceTempView("dorchester_table")

# %%
spark.sql("""SELECT room_type, count(room_type), ROUND(avg(price), 2) as average_price 
            FROM dorchester_table
            GROUP BY room_type
            ORDER BY average_price""").show()
# Out:
# +---------------+----------------+-------------+
# |      room_type|count(room_type)|average_price|
# +---------------+----------------+-------------+
# |   Private room|           15297|        82.21|
# |     Hotel room|             153|       130.36|
# |Entire home/apt|            4066|       149.55|
# +---------------+----------------+-------------+

# %%
url = "http://data.insideairbnb.com/united-states/ma/boston/2020-06-10/visualizations/listings.csv"
spark.read.csv(url, header=True)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-70-cbec41ce3507> in <module>
#       1 url = "http://data.insideairbnb.com/united-states/ma/boston/2020-06-10/visualizations/listings.csv"
# ----> 2 spark.read.csv(url, header=True)
#
# /usr/local/spark/python/pyspark/sql/readwriter.py in csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue)
#     474             path = [path]
#     475         if type(path) == list:
# --> 476             return self._df(self._jreader.csv(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#     477         elif isinstance(path, RDD):
#     478             def func(iterator):
#
# /usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# /usr/local/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# /usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     326                 raise Py4JJavaError(
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#     330                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o517.csv.
# : java.io.IOException: No FileSystem for scheme: http
# 	at org.apache.hadoop.fs.FileSystem.getFileSystemClass(FileSystem.java:2660)
# 	at org.apache.hadoop.fs.FileSystem.createFileSystem(FileSystem.java:2667)
# 	at org.apache.hadoop.fs.FileSystem.access$200(FileSystem.java:94)
# 	at org.apache.hadoop.fs.FileSystem$Cache.getInternal(FileSystem.java:2703)
# 	at org.apache.hadoop.fs.FileSystem$Cache.get(FileSystem.java:2685)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:373)
# 	at org.apache.hadoop.fs.Path.getFileSystem(Path.java:295)
# 	at org.apache.spark.sql.execution.datasources.DataSource$$anonfun$org$apache$spark$sql$execution$datasources$DataSource$$checkAndGlobPathIfNecessary$1.apply(DataSource.scala:547)
# 	at org.apache.spark.sql.execution.datasources.DataSource$$anonfun$org$apache$spark$sql$execution$datasources$DataSource$$checkAndGlobPathIfNecessary$1.apply(DataSource.scala:545)
# 	at scala.collection.TraversableLike$$anonfun$flatMap$1.apply(TraversableLike.scala:241)
# 	at scala.collection.TraversableLike$$anonfun$flatMap$1.apply(TraversableLike.scala:241)
# 	at scala.collection.immutable.List.foreach(List.scala:392)
# 	at scala.collection.TraversableLike$class.flatMap(TraversableLike.scala:241)
# 	at scala.collection.immutable.List.flatMap(List.scala:355)
# 	at org.apache.spark.sql.execution.datasources.DataSource.org$apache$spark$sql$execution$datasources$DataSource$$checkAndGlobPathIfNecessary(DataSource.scala:545)
# 	at org.apache.spark.sql.execution.datasources.DataSource.resolveRelation(DataSource.scala:359)
# 	at org.apache.spark.sql.DataFrameReader.loadV1Source(DataFrameReader.scala:223)
# 	at org.apache.spark.sql.DataFrameReader.load(DataFrameReader.scala:211)
# 	at org.apache.spark.sql.DataFrameReader.csv(DataFrameReader.scala:619)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)

# %%
url = "https://data.insideairbnb.com/united-states/ma/boston/2020-06-10/visualizations/listings.csv"
from pyspark import SparkFiles
spark.sparkContext.addFile(url)

# %%
spark.read.csv("file://"+SparkFiles.get("listings.csv"), header=True)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /usr/local/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# /usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o609.csv.
# : org.apache.spark.sql.AnalysisException: Path does not exist: file:/tmp/spark-e9bf86f1-2c41-44e6-8e8f-721103584c5c/userFiles-6363795a-f8b7-42ab-b48e-2f9570027006/listings.csv;
# 	at org.apache.spark.sql.execution.datasources.DataSource$$anonfun$org$apache$spark$sql$execution$datasources$DataSource$$checkAndGlobPathIfNecessary$1.apply(DataSource.scala:558)
# 	at org.apache.spark.sql.execution.datasources.DataSource$$anonfun$org$apache$spark$sql$execution$datasources$DataSource$$checkAndGlobPathIfNecessary$1.apply(DataSource.scala:545)
# 	at scala.collection.TraversableLike$$anonfun$flatMap$1.apply(TraversableLike.scala:241)
# 	at scala.collection.TraversableLike$$anonfun$flatMap$1.apply(TraversableLike.scala:241)
# 	at scala.collection.immutable.List.foreach(List.scala:392)
# 	at scala.collection.TraversableLike$class.flatMap(TraversableLike.scala:241)
# 	at scala.collection.immutable.List.flatMap(List.scala:355)
# 	at org.apache.spark.sql.execution.datasources.DataSource.org$apache$spark$sql$execution$datasources$DataSource$$checkAndGlobPathIfNecessary(DataSource.scala:545)
# 	at org.apache.spark.sql.execution.datasources.DataSource.resolveRelation(DataSource.scala:359)
# 	at org.apache.spark.sql.DataFrameReader.loadV1Source(DataFrameReader.scala:223)
# 	at org.apache.spark.sql.DataFrameReader.load(DataFrameReader.scala:211)
# 	at org.apache.spark.sql.DataFrameReader.csv(DataFrameReader.scala:619)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-76-a6853d2a137b> in <module>
# ----> 1 spark.read.csv("file://"+SparkFiles.get("listings.csv"), header=True)
#
# /usr/local/spark/python/pyspark/sql/readwriter.py in csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue)
#     474             path = [path]
#     475         if type(path) == list:
# --> 476             return self._df(self._jreader.csv(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#     477         elif isinstance(path, RDD):
#     478             def func(iterator):
#
# /usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# /usr/local/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      67                                              e.java_exception.getStackTrace()))
#      68             if s.startswith('org.apache.spark.sql.AnalysisException: '):
# ---> 69                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#      70             if s.startswith('org.apache.spark.sql.catalyst.analysis'):
#      71                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#
# AnalysisException: 'Path does not exist: file:/tmp/spark-e9bf86f1-2c41-44e6-8e8f-721103584c5c/userFiles-6363795a-f8b7-42ab-b48e-2f9570027006/listings.csv;'

# %%
from pyspark import SparkFiles
url = "http://data.insideairbnb.com/united-states/ma/boston/2020-06-10/visualisations/listings.csv"
spark.sparkContext.addFile(url)

# %%
spark.read.csv(SparkFiles.get("listings.csv"), header=True).toPandas()
# Out:
#             id                                               name    host_id  \
# 0         3781                          HARBORSIDE-Walk to subway       4804
# 1         5506     **$49 Special **   Private! Minutes to center!       8229
# 2         6695                     $99 Special!! Home Away! Condo       8229
# 3         8789                Curved Glass Studio/1bd facing Park      26988
# 4        10730                     Bright 1bed facing Golden Dome      26988
# ...        ...                                                ...        ...
# 3441  43690671            Beautiful 2 bedroom apartment/2nd floor  127718668
# 3442  43690782            Beautiful 2-bedroom apartment/3rd floor  127718668
# 3443  43715032                  2.bostonparkplaza · SUPERIOR ROOM  243931054
# 3444  43715125                                     Private Escape  349225095
# 3445  43729521  Evonify - MGH & Tufts - Luxury 2BR in Downtown PH  212359760
#
#               host_name neighbourhood_group neighbourhood           latitude  \
# 0                 Frank                None   East Boston           42.36413
# 1                 Terry                None       Roxbury           42.32981
# 2                 Terry                None       Roxbury           42.32994
# 3                  Anne                None      Downtown           42.35919
# 4                  Anne                None      Downtown            42.3584
# ...                 ...                 ...           ...                ...
# 3441               Muny                None    Dorchester           42.31281
# 3442               Muny                None    Dorchester           42.31235
# 3443  Boston Park Plaza                None      Downtown           42.35167
# 3444             Trevor                None    Dorchester           42.29637
# 3445            Evonify                None      Downtown  42.35106002536211
#
#               longitude        room_type price minimum_nights  \
# 0             -71.02991  Entire home/apt   125             28
# 1             -71.09559  Entire home/apt   145              3
# 2             -71.09351  Entire home/apt   169              3
# 3             -71.06265  Entire home/apt    99             91
# 4             -71.06185  Entire home/apt   150             91
# ...                 ...              ...   ...            ...
# 3441          -71.05591  Entire home/apt   170              1
# 3442           -71.0553  Entire home/apt   170              1
# 3443          -71.07058       Hotel room   100              1
# 3444          -71.07314     Private room    90              1
# 3445  -71.0650582770758  Entire home/apt   299              1
#
#      number_of_reviews last_review reviews_per_month  \
# 0                   16  2019-12-21              0.27
# 1                  107  2020-05-01              0.78
# 2                  115  2019-11-02              0.87
# 3                   25  2020-04-15              0.35
# 4                   32  2020-04-16              0.25
# ...                ...         ...               ...
# 3441                 0        None              None
# 3442                 0        None              None
# 3443                 0        None              None
# 3444                 0        None              None
# 3445                 0        None              None
#
#      calculated_host_listings_count availability_365
# 0                                 1               97
# 1                                 6              333
# 2                                 6              317
# 3                                 8              365
# 4                                 8              282
# ...                             ...              ...
# 3441                             13              363
# 3442                             13              361
# 3443                             13              348
# 3444                              1               84
# 3445                             46              365
#
# [3446 rows x 16 columns]

# %%
url = "http://data.insideairbnb.com/united-states/ma/boston/2020-06-10/visualisations/"
listings_url = url + "listings.csv"
reviews_url = url + "reviews.csv"
spark.sparkContext.addFile(listings_url)
spark.sparkContext.addFile(reviews_url)

# %%
listings_df = spark.read.csv(SparkFiles.get("listings.csv"), header=True)
listings_df.toPandas()
# Out:
#             id                                               name    host_id  \
# 0         3781                          HARBORSIDE-Walk to subway       4804
# 1         5506     **$49 Special **   Private! Minutes to center!       8229
# 2         6695                     $99 Special!! Home Away! Condo       8229
# 3         8789                Curved Glass Studio/1bd facing Park      26988
# 4        10730                     Bright 1bed facing Golden Dome      26988
# ...        ...                                                ...        ...
# 3441  43690671            Beautiful 2 bedroom apartment/2nd floor  127718668
# 3442  43690782            Beautiful 2-bedroom apartment/3rd floor  127718668
# 3443  43715032                  2.bostonparkplaza · SUPERIOR ROOM  243931054
# 3444  43715125                                     Private Escape  349225095
# 3445  43729521  Evonify - MGH & Tufts - Luxury 2BR in Downtown PH  212359760
#
#               host_name neighbourhood_group neighbourhood           latitude  \
# 0                 Frank                None   East Boston           42.36413
# 1                 Terry                None       Roxbury           42.32981
# 2                 Terry                None       Roxbury           42.32994
# 3                  Anne                None      Downtown           42.35919
# 4                  Anne                None      Downtown            42.3584
# ...                 ...                 ...           ...                ...
# 3441               Muny                None    Dorchester           42.31281
# 3442               Muny                None    Dorchester           42.31235
# 3443  Boston Park Plaza                None      Downtown           42.35167
# 3444             Trevor                None    Dorchester           42.29637
# 3445            Evonify                None      Downtown  42.35106002536211
#
#               longitude        room_type price minimum_nights  \
# 0             -71.02991  Entire home/apt   125             28
# 1             -71.09559  Entire home/apt   145              3
# 2             -71.09351  Entire home/apt   169              3
# 3             -71.06265  Entire home/apt    99             91
# 4             -71.06185  Entire home/apt   150             91
# ...                 ...              ...   ...            ...
# 3441          -71.05591  Entire home/apt   170              1
# 3442           -71.0553  Entire home/apt   170              1
# 3443          -71.07058       Hotel room   100              1
# 3444          -71.07314     Private room    90              1
# 3445  -71.0650582770758  Entire home/apt   299              1
#
#      number_of_reviews last_review reviews_per_month  \
# 0                   16  2019-12-21              0.27
# 1                  107  2020-05-01              0.78
# 2                  115  2019-11-02              0.87
# 3                   25  2020-04-15              0.35
# 4                   32  2020-04-16              0.25
# ...                ...         ...               ...
# 3441                 0        None              None
# 3442                 0        None              None
# 3443                 0        None              None
# 3444                 0        None              None
# 3445                 0        None              None
#
#      calculated_host_listings_count availability_365
# 0                                 1               97
# 1                                 6              333
# 2                                 6              317
# 3                                 8              365
# 4                                 8              282
# ...                             ...              ...
# 3441                             13              363
# 3442                             13              361
# 3443                             13              348
# 3444                              1               84
# 3445                             46              365
#
# [3446 rows x 16 columns]

# %%
reviews_df = spark.read.csv(SparkFiles.get("reviews.csv"), header=True)
reviews_df.toPandas()
# Out:
#        listing_id        date
# 0            3781  2015-07-10
# 1            3781  2015-08-09
# 2            3781  2015-09-01
# 3            3781  2015-09-30
# 4            3781  2015-10-30
# ...           ...         ...
# 140887   43257845  2020-05-17
# 140888   43442619  2020-05-18
# 140889   43442619  2020-05-29
# 140890   43489770  2020-06-05
# 140891   43508236  2020-05-29
#
# [140892 rows x 2 columns]

# %%
reviews_url = "http://data.insideairbnb.com/united-states/ma/boston/2020-06-10/data/reviews.csv.gz"
spark.sparkContext.addFile(reviews_url)

# %%
spark.read.option("header", "true").csv(SparkFiles.get("reviews.csv.gz")).show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+-------------+--------------------+
# |          listing_id|                  id|                date|         reviewer_id|reviewer_name|            comments|
# +--------------------+--------------------+--------------------+--------------------+-------------+--------------------+
# |                3781|            37776825|          2015-07-10|            36059247|         Greg|The apartment was...|
# |                3781|            41842494|          2015-08-09|            10459388|          Tai|It was a pleasure...|
# |                3781|            45282151|          2015-09-01|            12264652|       Damien|The apartment des...|
# |                3781|            49022647|          2015-09-30|            41426327|         Mike|Thoroughly enjoye...|
# |                3781|            52503327|          2015-10-30|            15151513|         Ivan|Great value for t...|
# |1. Photos don't d...|                null|                null|                null|         null|                null|
# |2. The location i...| which takes you ...| with a stop at t...|                null|         null|                null|
# |3. Despite being ...| the house is ver...| and I didn't hav...| so it means that...|         null|                null|
# |4. Responsive but...|                null|                null|                null|         null|                null|
# |                3781|            63371931|          2016-02-22|            55456499|    John-Mark|Frank was very ac...|
# |Upon entry it is ...|                null|                null|                null|         null|                null|
# |                   "|                null|                null|                null|         null|                null|
# |                3781|            67909504|          2016-04-01|            55456499|    John-Mark|Excellent! This w...|
# |                3781|            97906006|          2016-08-28|            88528884|        Elisa|Frank was a wonde...|
# |                3781|           105143774|          2016-09-30|             1342806|       Nicole|Frank was great, ...|
# |                3781|           129692749|          2017-02-01|            55126634|       Carlos|Very nice. Comfor...|
# |                3781|           155725362|          2017-05-28|           117390053|      Carolyn|"Apartment was ev...|
# |                3781|           184356065|          2017-08-19|            70187382|       Justin|Frank's place is ...|
# |                3781|           194026175|          2017-09-15|            11888800|         John|Franks' place is ...|
# |                3781|           284969158|          2018-07-02|           173840231|        Artur|Great place, amaz...|
# +--------------------+--------------------+--------------------+--------------------+-------------+--------------------+
# only showing top 20 rows

# %%
url = "http://data.insideairbnb.com/united-states/ma/boston/2020-05-12/data/reviews.csv.gz"
spark.sparkContext.addFile(reviews_url)

# %%
spark.read.option("header", "true").csv(SparkFiles.get("reviews.csv.gz")).show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+-------------+--------------------+
# |          listing_id|                  id|                date|         reviewer_id|reviewer_name|            comments|
# +--------------------+--------------------+--------------------+--------------------+-------------+--------------------+
# |                3781|            37776825|          2015-07-10|            36059247|         Greg|The apartment was...|
# |                3781|            41842494|          2015-08-09|            10459388|          Tai|It was a pleasure...|
# |                3781|            45282151|          2015-09-01|            12264652|       Damien|The apartment des...|
# |                3781|            49022647|          2015-09-30|            41426327|         Mike|Thoroughly enjoye...|
# |                3781|            52503327|          2015-10-30|            15151513|         Ivan|Great value for t...|
# |1. Photos don't d...|                null|                null|                null|         null|                null|
# |2. The location i...| which takes you ...| with a stop at t...|                null|         null|                null|
# |3. Despite being ...| the house is ver...| and I didn't hav...| so it means that...|         null|                null|
# |4. Responsive but...|                null|                null|                null|         null|                null|
# |                3781|            63371931|          2016-02-22|            55456499|    John-Mark|Frank was very ac...|
# |Upon entry it is ...|                null|                null|                null|         null|                null|
# |                   "|                null|                null|                null|         null|                null|
# |                3781|            67909504|          2016-04-01|            55456499|    John-Mark|Excellent! This w...|
# |                3781|            97906006|          2016-08-28|            88528884|        Elisa|Frank was a wonde...|
# |                3781|           105143774|          2016-09-30|             1342806|       Nicole|Frank was great, ...|
# |                3781|           129692749|          2017-02-01|            55126634|       Carlos|Very nice. Comfor...|
# |                3781|           155725362|          2017-05-28|           117390053|      Carolyn|"Apartment was ev...|
# |                3781|           184356065|          2017-08-19|            70187382|       Justin|Frank's place is ...|
# |                3781|           194026175|          2017-09-15|            11888800|         John|Franks' place is ...|
# |                3781|           284969158|          2018-07-02|           173840231|        Artur|Great place, amaz...|
# +--------------------+--------------------+--------------------+--------------------+-------------+--------------------+
# only showing top 20 rows

# %%
url = "http://data.insideairbnb.com/united-states/ma/boston/2020-05-12/visualisations/listings.csv"
spark.sparkContext.addFile(url)

# %%
spark.read.csv(SparkFiles.get("listings.csv"), header=True).show()
# Out:
# +-----+--------------------+-------+----------+-------------------+-------------+--------+---------+---------------+-----+--------------+-----------------+-----------+-----------------+------------------------------+----------------+
# |   id|                name|host_id| host_name|neighbourhood_group|neighbourhood|latitude|longitude|      room_type|price|minimum_nights|number_of_reviews|last_review|reviews_per_month|calculated_host_listings_count|availability_365|
# +-----+--------------------+-------+----------+-------------------+-------------+--------+---------+---------------+-----+--------------+-----------------+-----------+-----------------+------------------------------+----------------+
# | 3781|HARBORSIDE-Walk t...|   4804|     Frank|               null|  East Boston|42.36413|-71.02991|Entire home/apt|  125|            28|               16| 2019-12-21|             0.27|                             1|              91|
# | 5506|**$49 Special ** ...|   8229|     Terry|               null|      Roxbury|42.32981|-71.09559|Entire home/apt|  145|             3|              107| 2020-05-01|             0.79|                             6|             344|
# | 6695|$99 Special!! Hom...|   8229|     Terry|               null|      Roxbury|42.32994|-71.09351|Entire home/apt|  169|             3|              115| 2019-11-02|             0.88|                             6|             297|
# | 8789|Curved Glass Stud...|  26988|      Anne|               null|     Downtown|42.35919|-71.06265|Entire home/apt|   99|            91|               25| 2020-04-15|             0.36|                             8|             302|
# |10730|Bright 1bed facin...|  26988|      Anne|               null|     Downtown| 42.3584|-71.06185|Entire home/apt|  150|            91|               32| 2020-04-16|             0.25|                             8|             121|
# |10813|Back Bay Apt-bloc...|  38997|  Michelle|               null|     Back Bay|42.34961|-71.08904|Entire home/apt|  179|            28|               80| 2020-03-08|             2.65|                             9|               0|
# |10986|Waterfront/North ...|  38997|  Michelle|               null|    North End|42.36352|-71.05075|Entire home/apt|  125|            28|                2| 2016-05-23|             0.04|                             9|             364|
# |16384|Small Room in Cam...|  23078|      Eric|               null|  Beacon Hill| 42.3581|-71.07132|   Private room|   50|            91|                0|       null|             null|                             1|             365|
# |18711|The Dorset Redlin...|  71783|     Lance|               null|   Dorchester|42.32212|-71.06096|Entire home/apt|  154|            29|               52| 2019-10-05|             0.43|                            39|             365|
# |22195|Copley House - Pr...|  85130|    Copley|               null|     Back Bay|42.34558| -71.0793|   Private room|  115|             1|               21| 2020-02-08|             0.17|                             6|             299|
# |22354|COPLEY SQ...19TH ...|  85770|    Robert|               null|    South End|42.34496|-71.07486|   Private room|  148|             2|              316| 2019-12-13|             2.96|                             5|              89|
# |24240|The Golden Slippe...|  97821|  Gretchen|               null|    North End|42.36366|-71.05023|Entire home/apt|  275|             2|              103| 2019-10-03|             0.88|                             1|             295|
# |29765|Luxury suite, Mor...| 128280| Elizabeth|               null|  Charlestown|42.37754|-71.06642|Entire home/apt|  221|             2|               93| 2018-10-21|             0.77|                             2|             289|
# |40601|Private room & ba...| 174986|    Robert|               null|Jamaica Plain| 42.3151|-71.11108|   Private room|   95|            28|               75| 2019-11-04|             0.63|                             1|             281|
# |45987|Gorgeous Garden S...| 205107|      Atef|               null|  Charlestown|42.37404|-71.06118|Entire home/apt|  125|             3|              130| 2019-12-10|             1.10|                             1|              89|
# |60029|Room in geographi...| 255183|  Michelle|               null|      Roxbury|42.32584|-71.08927|   Private room|   75|             2|              141| 2019-08-13|             1.24|                             5|              75|
# |60356|Bookcase 1bd faci...|  26988|      Anne|               null|     Downtown|42.35712| -71.0618|Entire home/apt|  175|            32|               18| 2018-11-05|             0.23|                             8|             364|
# |67774|Corner 1 bed faci...|  26988|      Anne|               null|  Beacon Hill|42.35867|-71.06332|Entire home/apt|  110|            32|               44| 2019-10-30|             0.48|                             8|             364|
# |69369|Room in Boston of...| 255183|  Michelle|               null|      Roxbury|42.32614| -71.0884|   Private room|   79|             2|              120| 2019-11-15|             1.10|                             5|              59|
# |77681|Waterfall Room: B...| 416912|Christiane|               null|  Charlestown|42.37853|-71.06177|   Private room|  140|             2|               54| 2019-11-02|             0.51|                             1|             365|
# +-----+--------------------+-------+----------+-------------------+-------------+--------+---------+---------------+-----+--------------+-----------------+-----------+-----------------+------------------------------+----------------+
# only showing top 20 rows

# %%
url = "http://data.insideairbnb.com/united-states/ma/boston/2016-09-07/visualisations/listings.csv"
spark.sparkContext.addFile(url)

# %%
spark.read.csv(SparkFiles.get("listings.csv"), header=True).show()
# Out:
# +--------+--------------------+--------+---------+-------------------+-------------+------------------+------------------+---------------+-----+--------------+-----------------+-----------+-----------------+------------------------------+----------------+
# |      id|                name| host_id|host_name|neighbourhood_group|neighbourhood|          latitude|         longitude|      room_type|price|minimum_nights|number_of_reviews|last_review|reviews_per_month|calculated_host_listings_count|availability_365|
# +--------+--------------------+--------+---------+-------------------+-------------+------------------+------------------+---------------+-----+--------------+-----------------+-----------+-----------------+------------------------------+----------------+
# |12147973|Sunny Bungalow in...|31303940| Virginia|               null|   Roslindale|42.282618795779484|-71.13306792912681|Entire home/apt|  250|             2|                0|       null|             null|                             1|               0|
# | 3075044|Charming room in ...| 2572247|   Andrea|               null|   Roslindale|42.286240821867416|-71.13437396457161|   Private room|   65|             2|               36| 2016-08-13|             1.30|                             1|             359|
# |    6976|Mexican Folk Art ...|   16701|     Phil|               null|   Roslindale|  42.2924378866568|-71.13576525374667|   Private room|   65|             3|               41| 2016-08-05|             0.47|                             1|             319|
# | 1436513|Spacious Sunny Be...| 6031442|   Meghna|               null|   Roslindale| 42.28110618827366|-71.12102117350553|   Private room|   75|             1|                1| 2016-08-28|                1|                             1|              98|
# | 7651065| Come Home to Boston|15396970|    Linda|               null|   Roslindale| 42.28451220982457| -71.1362580468337|   Private room|   79|             2|               29| 2016-09-01|             2.25|                             1|             334|
# |12386020|Private Bedroom +...|64200298|  Deborah|               null|   Roslindale| 42.29168980076903|-71.13189277475922|   Private room|   75|             2|                8| 2016-08-28|             1.70|                             1|              58|
# | 5706985|New Lrg Studio ap...| 6570877|   Juliet|               null|   Roslindale| 42.28138962623448|-71.13119041987277|Entire home/apt|  100|             1|               57| 2016-09-01|             4.00|                             3|             344|
# | 2843445|"""Tranquility"" ...| 3164508|  Marilyn|               null|   Roslindale| 42.28194609607024|-71.14102161135577|   Private room|   75|             1|               67| 2016-09-04|             2.38|                             2|             365|
# |  753446|6 miles away from...| 3962517|     Sami|               null|   Roslindale| 42.28587763920193|-71.12490955692161|   Private room|   58|             2|               65| 2016-08-30|             5.36|                             1|             347|
# |  849408|Perfect & Practic...| 4434391|    Damon|               null|   Roslindale| 42.28882028358453|-71.13951010210121|Entire home/apt|  229|             4|               33| 2016-05-27|             1.01|                             2|             107|
# |12023024|Cozy room in a we...|64331842|  Ricardo|               null|   Roslindale|42.286448197788786|-71.13932538848039|   Private room|   60|             1|                1| 2016-06-17|             0.36|                             1|             343|
# | 1668313|Room in Rozzie-Tw...| 8834105|  Rebecca|               null|   Roslindale|42.281941832424685|-71.13337190191741|   Private room|   57|             1|               17| 2016-08-18|             0.48|                             2|             341|
# | 2684840|Updated, spacious...|13743098|    Megan|               null|   Roslindale| 42.29172341146307|-71.13155602161845|Entire home/apt|   93|             1|                1| 2016-07-23|             0.64|                             2|               0|
# |13547301|2 Bedroom Apartme...|57402911|  Georgia|               null|   Roslindale| 42.28764103470109|-71.12988286590424|Entire home/apt|  150|             2|               12| 2016-09-03|             4.93|                             1|             129|
# | 5434353|Quiet  Beauty in ...| 9658771|  Anthony|               null|   Roslindale|42.286264736208935|-71.13706513072117|Entire home/apt|  145|             3|                7| 2016-08-06|             0.56|                             1|             319|
# |  225979|Cozy Room & Fresh...| 1176995|    Duane|               null|   Roslindale|  42.2814520694321|-71.12925004404066|   Private room|   60|             1|               70| 2016-08-02|             1.16|                             2|             339|
# | 3420384|Convient, Safe an...|  431385|  Cynthia|               null|   Roslindale| 42.27440801253166|-71.12529404441553|   Private room|  165|             3|                1| 2016-08-26|                1|                             1|             349|
# |13512930|Roslindale Beauty...|13743098|    Megan|               null|   Roslindale| 42.29181491557826| -71.1315879343071|   Private room|   75|             1|                1| 2016-06-20|             0.37|                             2|               0|
# | 7482195|Private room near...|34552909|   Barrie|               null|   Roslindale|42.282224755841604|-71.11518855890074|   Private room|   49|             5|                0|       null|             null|                             3|             295|
# | 7252607|Private Room near...|34552909|   Barrie|               null|   Roslindale| 42.28280175042395|-71.11514509094087|   Private room|   49|             5|                4| 2016-08-21|             0.29|                             3|             262|
# +--------+--------------------+--------+---------+-------------------+-------------+------------------+------------------+---------------+-----+--------------+-----------------+-----------+-----------------+------------------------------+----------------+
# only showing top 20 rows

# %%
spark.getConf().getAll()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-9156ffea71d7> in <module>
# ----> 1 spark.getConf().getAll()
#
# AttributeError: 'SparkSession' object has no attribute 'getConf'
